# %%
import numpy as np
import matplotlib.pylab as plt

# %%
import maskshop.shape

mask = (
    maskshop.shape.new((150, 150))
    .circle(sigma=25.0, offsetH=10)
    .horizontalLine(sigma=5.0, offset=-10)
    .verticalLine(sigma=5.0, offset=-20)
)

plt.imshow(mask.make())
plt.show()
